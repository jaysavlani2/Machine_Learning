# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive #to import google drive data

# %%
drive.mount('/content/drive') #to mount the drive data into colab clound and enter the activation code
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/"My Drive/Colab Notebooks/Workshop"
# Out:
# /content/drive/My Drive/Colab Notebooks/Workshop

# %%
dataset=pd.read_csv("insurance.csv")
print(dataset)
dataset.shape
# Out:
#      age  sex     bmi  children  smoker  region      charges
# 0     19    0  27.900         0       1       3  16884.92400
# 1     18    1  33.770         1       0       2   1725.55230
# 2     28    1  33.000         3       0       2   4449.46200
# 3     33    1  22.705         0       0       1  21984.47061
# 4     32    1  28.880         0       0       1   3866.85520
# ..   ...  ...     ...       ...     ...     ...          ...
# 343   63    1  36.765         0       0       0  13981.85035
# 344   49    0  41.470         4       0       2  10977.20630
# 345   34    0  29.260         3       0       2   6184.29940
# 346   33    1  35.750         2       0       2   4889.99950
# 347   46    1  33.345         1       0       0   8334.45755
#
# [348 rows x 7 columns]
# (348, 7)

# %%
x_value=dataset.iloc[0:348,0:6]

# %%
x_value
# Out:
#      age  sex     bmi  children  smoker  region
# 0     19    0  27.900         0       1       3
# 1     18    1  33.770         1       0       2
# 2     28    1  33.000         3       0       2
# 3     33    1  22.705         0       0       1
# 4     32    1  28.880         0       0       1
# ..   ...  ...     ...       ...     ...     ...
# 343   63    1  36.765         0       0       0
# 344   49    0  41.470         4       0       2
# 345   34    0  29.260         3       0       2
# 346   33    1  35.750         2       0       2
# 347   46    1  33.345         1       0       0
#
# [348 rows x 6 columns]

# %%
y_value=dataset.iloc[0:348,6:7]

# %%
y_value
# Out:
#          charges
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# ..           ...
# 343  13981.85035
# 344  10977.20630
# 345   6184.29940
# 346   4889.99950
# 347   8334.45755
#
# [348 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x_value,y_value,test_size=0.2,random_state=42)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (278, 6)
# (70, 6)
# (278, 1)
# (70, 1)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train,Y_train)
reg.score(X_train,Y_train)
# Out:
# 0.7609080253266194
