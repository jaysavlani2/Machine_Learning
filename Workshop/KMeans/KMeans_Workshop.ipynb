# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive #to import google drive data

# %%
drive.mount('/content/drive') #to mount the drive data into colab clound and enter the activation code
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/"My Drive/Colab Notebooks/Workshop/KMeans"
# Out:
# /content/drive/My Drive/Colab Notebooks/Workshop/KMeans

# %%
df=pd.read_csv('htwt.csv')

# %%
df.head()
# Out:
#    Height  Weight
# 0     185      72
# 1     170      56
# 2     168      60
# 3     179      68
# 4     182      72

# %%
plt.scatter(df['Height'],df['Weight'])
plt.show()

# %%
#Elbow Method to find k
distortions = []
K = range(1,13)
for i in K:
    model_demo = KMeans(n_clusters=i,random_state=0)
    model_demo.fit(df)
    distortions.append(model_demo.inertia_)
plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
#Both columns are considered as inputs
x=df.values

# %%
from sklearn.cluster import KMeans

# %%
model=KMeans(n_clusters=3,random_state=0)
model.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=0, tol=0.0001, verbose=0)

# %%
y=model.predict(x)
y
# Out:
# array([0, 2, 2, 0, 0, 1, 0, 0, 1, 1, 0, 0], dtype=int32)

# %%
#Cluster 0 and heigth
x[y==0,0]
# Out:
# array([185, 179, 182, 188, 180, 180, 183, 180, 180, 177])

# %%
#Cluster 0 and weight
x[y==0,1]
# Out:
# array([72, 68, 72, 77, 71, 70, 84, 88, 67, 76])

# %%
#Cluster 1 and heigth
x[y==1,0]
# Out:
# array([170, 168])

# %%
#Cluster 1 and weight
x[y==1,1]
# Out:
# array([56, 60])

# %%
plt.scatter(x[y==0,0],x[y==0,1])
plt.scatter(x[y==1,0],x[y==1,1])
plt.scatter(x[y==2,0],x[y==2,1])
